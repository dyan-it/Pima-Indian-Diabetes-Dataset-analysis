# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD

# %%
# 파일 읽기
df = pd.read_csv('./diabetes.csv')

# %%
# 데이터 분리
X_data = df.drop(['Outcome'], axis = 1)
Y_data = df[['Outcome']]

# %%
# 정규화 (0-1사이 값으로 변환)
scaler = MinMaxScaler()
scaler.fit(X_data)
norm_X_data = scaler.transform(X_data)

# %%
# train, test 데이터 분리 (7:3)
train_x, test_x, train_y, test_y = train_test_split(norm_X_data, Y_data, test_size = 0.3, random_state=1)

# %%
train_x.shape
# Out:
# (537, 8)

# %%
# Flatten(2차원으로 변환)
model = Sequential()
model.add(Flatten())   #전체 4차원에서 2차원으로 바꾸어줌
model.add(Dense(units = 256, activation = 'relu'))
model.add(Dense(units = 128, activation = 'relu'))
model.add(Dense(units = 64, activation = 'softmax'))

# %%
# Compile
model.compile(optimizer = SGD(learning_rate = 0.0001), 
             loss = 'sparse_categorical_crossentropy',
             metrics = 'accuracy')

# %%
# 모델 학습
model.fit(train_x, train_y, epochs = 100, batch_size = 10,
         verbose = 1,
         validation_split = 0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 0s 5ms/step - loss: 4.1290 - accuracy: 0.0000e+00 - val_loss: 4.1302 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1228 - accuracy: 0.0000e+00 - val_loss: 4.1241 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1166 - accuracy: 0.0000e+00 - val_loss: 4.1181 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1104 - accuracy: 0.0000e+00 - val_loss: 4.1120 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.1042 - accuracy: 0.0000e+00 - val_loss: 4.1059 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 43/43 [==============================] - 0s 2ms/step - loss: 4.0979 - accuracy: 0.0000e+00 - val_loss: 4.0998 - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...
